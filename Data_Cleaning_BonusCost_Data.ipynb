# %% [markdown]
# <a href="https://colab.research.google.com/github/toVivekNailwal/Data-Analytics-Portfolio/blob/main/Data_Cleaning_BonusCost_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
bonus_cost = pd.read_excel('BonusCost_Data.xlsx', header=1)

# %%
#removing 'Unnamed: 0' column permanently
bonus_cost.drop(columns=["Unnamed: 0"], inplace=True)

# %%
bonus_cost
# Out:
#         Src_PLAYER_ID ActivityMonth     Product  BONUS_COST
# 0            16051927    2020-06-30     eGaming        50.0
# 1            19309540    2021-02-28     eGaming        40.0
# 2            13176431    2020-01-31     eGaming        15.0
# 3            12405628    2019-02-28  SportsBook        30.0
# 4            17486248    2021-02-28     eGaming        25.0
# ...               ...           ...         ...         ...
# 207065       12655588    2020-12-31     eGaming        20.0
# 207066       15199116    2020-03-31     eGaming       100.0
# 207067       18399633    2020-12-31     eGaming        25.0
# 207068       15298566    2020-06-30     eGaming        20.0
# 207069       19696774    2021-03-31     eGaming       125.0
#
# [207070 rows x 4 columns]

# %%
#starting indexing from 1
bonus_cost.index+=1
bonus_cost
# Out:
#         Src_PLAYER_ID ActivityMonth     Product  BONUS_COST
# 1            16051927    2020-06-30     eGaming        50.0
# 2            19309540    2021-02-28     eGaming        40.0
# 3            13176431    2020-01-31     eGaming        15.0
# 4            12405628    2019-02-28  SportsBook        30.0
# 5            17486248    2021-02-28     eGaming        25.0
# ...               ...           ...         ...         ...
# 207066       12655588    2020-12-31     eGaming        20.0
# 207067       15199116    2020-03-31     eGaming       100.0
# 207068       18399633    2020-12-31     eGaming        25.0
# 207069       15298566    2020-06-30     eGaming        20.0
# 207070       19696774    2021-03-31     eGaming       125.0
#
# [207070 rows x 4 columns]

# %%
bonus_cost.head(1)
# Out:
#    Player_Id       Date  Product  BONUS_COST
# 1   16051927 2020-06-30  eGaming        50.0

# %%
#renaming the column's name
bonus_cost.rename({'Src_PLAYER_ID': 'Player_Id', 'ActivityMonth':'Date',
                   'Product': 'Product', 'BONUS_COST': 'Bonus_Cost'}, axis=1, inplace=True)

# %%
bonus_cost
# Out:
#         Player_Id       Date     Product  Bonus_Cost
# 1        16051927 2020-06-30     eGaming        50.0
# 2        19309540 2021-02-28     eGaming        40.0
# 3        13176431 2020-01-31     eGaming        15.0
# 4        12405628 2019-02-28  SportsBook        30.0
# 5        17486248 2021-02-28     eGaming        25.0
# ...           ...        ...         ...         ...
# 207066   12655588 2020-12-31     eGaming        20.0
# 207067   15199116 2020-03-31     eGaming       100.0
# 207068   18399633 2020-12-31     eGaming        25.0
# 207069   15298566 2020-06-30     eGaming        20.0
# 207070   19696774 2021-03-31     eGaming       125.0
#
# [207070 rows x 4 columns]

# %%
bonus_cost['Date'] = bonus_cost['Date'].dt.strftime('%d/%m/%Y')

# %%
bonus_cost
# Out:
#         Player_Id        Date     Product  Bonus_Cost
# 1        16051927  30/06/2020     eGaming        50.0
# 2        19309540  28/02/2021     eGaming        40.0
# 3        13176431  31/01/2020     eGaming        15.0
# 4        12405628  28/02/2019  SportsBook        30.0
# 5        17486248  28/02/2021     eGaming        25.0
# ...           ...         ...         ...         ...
# 207066   12655588  31/12/2020     eGaming        20.0
# 207067   15199116  31/03/2020     eGaming       100.0
# 207068   18399633  31/12/2020     eGaming        25.0
# 207069   15298566  30/06/2020     eGaming        20.0
# 207070   19696774  31/03/2021     eGaming       125.0
#
# [207070 rows x 4 columns]
